# %% [markdown]
# <a href="https://colab.research.google.com/github/Prajwalsk45/Machine-Learning/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
from sklearn.datasets import 	load_diabetes
x, y =load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
plt.scatter(x[:,0],y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression as lg
model=lg()
model.fit(x_train,y_train)
pred=model.predict(x_test)
pred
# Out:
# array([119.14235853, 110.77183282, 185.03750644,  68.00997114,
#        171.05444208, 190.41916188, 218.59009744, 119.63375975,
#        157.26867822, 129.50082172, 214.15123432, 202.9228174 ,
#         88.41924038,  71.96523457, 236.88645879, 206.09667095,
#        175.60536299, 101.96502781, 114.10950995, 169.04562492,
#        187.71464103,  85.64466706, 144.1354953 , 107.06903899,
#         94.04844034, 211.79832988,  90.72839769, 176.23084464,
#        122.62288816, 180.92495472, 157.11598543, 138.04315918,
#        192.36322448,  94.45469648, 166.30860041, 189.43644667,
#        110.67690284, 247.6779722 , 172.47370249, 188.08959083,
#        160.08451415, 176.65318031, 115.81198266, 120.23187992,
#        141.5360933 , 203.4072105 , 152.43166715, 144.09802539,
#        190.18999626, 191.4950697 ,  59.81227803, 159.75688911,
#        102.14767931, 147.89042458, 186.10407036, 121.41211882,
#        159.12303468,  83.43835172,  55.57818196,  79.08303804,
# ...

# %%
from sklearn.metrics import  r2_score
r2_score(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-50-3611846270.py in <cell line: 0>()
#       1 from sklearn.metrics import  r2_score
# ----> 2 r2_score(x,y)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1255
#    1256     _, y_true, y_pred, sample_weight, multioutput = (
# -> 1257         _check_reg_targets_with_floating_dtype(
# ...

# %%
print("Acurracy/ R^2",model.score(x,y))
# Out:
# Acurracy/ R^2 0.5165572464147915

# %%
print("Coefficients:", model.coef_)
# Out:
# Coefficients: [ -30.62219046 -272.2506057   528.85252681  327.69716891 -581.01973841
#   332.97061365  -27.97314298  139.28036115  665.07667773   61.90517166]

# %%
print("Intercept (bias):", model.intercept_)
# Out:
# Intercept (bias): 151.4300932966009

# %%
model.intercept_
# Out:
# np.float64(151.4300932966009)
